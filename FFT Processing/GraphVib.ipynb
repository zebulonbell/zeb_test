# %%
import pandas as pd
import datetime as dt
import os
import sys
import pathlib
import matplotlib.pyplot as plt

# %%
x = pd.read_csv('failuretime.csv')

# %%
x1=x.drop(x[x.Name != 'HBR.VEY657202_02.PZ.X'].index)
x2=x.drop(x[x.Name != 'HBR.VEX657205_02.PZ.X'].index)

# %%
names=['HBR.VEY657202_02.PZ.X','HBR.VEX657212_01.PZ.X','HBR.VEX657202_03.PZ.X','HBR.VEY657205_02.PZ.X',
'HBR.VEY657202_06.PZ.X',
'HBR.VEZ657205_02.PZ.X',
'HBR.VEX657205_01.PZ.X',
'HBR.VEY657212_01.PZ.X',
'HBR.VEZ657202_04.PZ.X',
'HBR.VEY657205_01.PZ.X',
'HBR.VEX657202_01.PZ.X',
'HBR.VEX657202_02.PZ.X',
'HBR.VEY657202_01.PZ.X',
'HBR.VEY657202_03.PZ.X',
'HBR.VEY657202_05.PZ.X',
'HBR.VEX657202_05.PZ.X',
'HBR.VEX657202_06.PZ.X',
'HBR.VEX657205_02.PZ.X'
]

# %%
for i in names:
    y=x.drop(x[x.Name != i].index)
    plt.plot( y.time, y.reading)

# %%
plt.plot( x1.time, x1.reading)
plt.plot( x2.time, x2.reading)

# %%
print(x2)
# Out:
#                        Name    reading        time
# 8792  HBR.VEX657205_02.PZ.X  35.413677  3:30:07 AM
# 8793  HBR.VEX657205_02.PZ.X  35.608997  3:30:13 AM
# 8794  HBR.VEX657205_02.PZ.X  35.657826  3:30:17 AM
# 8795  HBR.VEX657205_02.PZ.X  35.608997  3:30:23 AM
# 8796  HBR.VEX657205_02.PZ.X  35.755485  3:30:27 AM
# ...                     ...        ...         ...
# 9395  HBR.VEX657205_02.PZ.X  44.135868  4:29:37 AM
# 9396  HBR.VEX657205_02.PZ.X  44.038208  4:29:43 AM
# 9397  HBR.VEX657205_02.PZ.X  43.647570  4:29:47 AM
# 9398  HBR.VEX657205_02.PZ.X  43.842890  4:29:53 AM
# 9399  HBR.VEX657205_02.PZ.X  43.794060  4:29:57 AM
#
# [608 rows x 3 columns]
